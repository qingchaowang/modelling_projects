# %% [markdown]
# This is a call_center exercise. Through this exercise, we want to find out which agent can approach the customers most efficiently (interested in the deal) and also which type of customer is more inclined to be interested in the deal given their characteristic features, i.e. age, working sector and residential region.

# %% [markdown]
# Import all related modules from Python

# %%
import pandas as pd
import os
import numpy as np
from pandas.api.types import CategoricalDtype
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
from scipy import stats
from statsmodels.formula.api import logit

# %% [markdown]
# Make sure data files and the program file are saved in the same directory

# %%
notebook_path = os.path.abspath('')

# %% [markdown]
# Load calls data

# %%
calls_data = pd.read_csv(notebook_path + '\\calls.csv')

# %% [markdown]
# Have a quick look at the data

# %%
calls_data.head(10)
# Out:
#    Phone Number     Call Outcome   Agent  Call Number
# 0   83473306392   NOT INTERESTED  orange            0
# 1  762850680150  CALL BACK LATER  orange            1
# 2  476309275079   NOT INTERESTED  orange            2
# 3  899921761538  CALL BACK LATER     red            3
# 4  906739234066  CALL BACK LATER  orange            4
# 5  112222295806        DEAD LINE  orange            5
# 6  631585844810   NOT INTERESTED  orange            6
# 7  611492586676        DEAD LINE     red            7
# 8  656565043793   NOT INTERESTED  orange            8
# 9  800543090846  CALL BACK LATER   green            9

# %% [markdown]
# Q1: which agent makes most calls

# %%
calls_data.groupby('Agent')['Agent'].count().sort_values(ascending = False)
# Out:
# Agent
# orange    2234
# red       1478
# black      750
# green      339
# blue       199
# Name: Agent, dtype: int64

# %% [markdown]
# Agent 'orange' apparently has far more calls made than others. But we are not sure whether he made a lot of useless calls or he called the customers effectively.

# %% [markdown]
# Among all customers received at least one call from us, we want to find how many calls we need to make in order for them to make a decision (sign up or not).

# %%
calls_data.groupby('Phone Number')['Phone Number'].count().mean()
# Out:
# 1.839587932303164

# %%
calls_data.shape[0]/(calls_data.drop_duplicates('Phone Number').shape[0])
# Out:
# 1.839587932303164

# %% [markdown]
# Alternatively, we could merge the two data sets between leads (customer characteristic file) and calls

# %%
leads_data = pd.read_csv(notebook_path + '\\leads.csv')

# %%
leads_data.head(10)
# Out:
#                 Name  Phone Number      Region        Sector  Age
# 0       Isabela MEZA  175718505368  north-west     wholesale   19
# 1       Deangelo LEE  937521423043  north-west        retail   38
# 2       Rosia MENDEZ  403640999962    midlands   agriculture   40
# 3  Jeremiah GALLOWAY  946740713605    scotland          food   23
# 4         Sarah POPE  264176984341    midlands        retail   18
# 5   Nolan VILLANUEVA  102993220908  north-west     wholesale   35
# 6         Wade AVERY  936057266681  south-west  construction   20
# 7      Karyn SHEPARD  416050061466    midlands        retail   60
# 8    Buster CALDERON  169044176823  south-west          food   21
# 9        Lu JACOBSON  477236163516  north-west   consultancy   28

# %%
leads_calls_left = pd.merge(leads_data, calls_data, how = 'left', on = 'Phone Number')

# %%
leads_calls_left.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12276 entries, 0 to 12275
# Data columns (total 8 columns):
# Name            12276 non-null object
# Phone Number    12276 non-null int64
# Region          12276 non-null object
# Sector          12276 non-null object
# Age             12276 non-null int64
# Call Outcome    5000 non-null object
# Agent           5000 non-null object
# Call Number     5000 non-null float64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 863.2+ KB

# %%
leads_calls_left[leads_calls_left['Call Outcome'].notnull()].groupby('Name')['Name'].count().mean()
# Out:
# 1.839587932303164

# %% [markdown]
# Focusing on the signed up leads only, calculate the average calls they received.

# %%
temp_data = pd.merge(calls_data, leads_data, on = 'Phone Number')
signups_data = pd.read_csv(notebook_path + '\\signups.csv')
signups_leads_calls = pd.merge(temp_data, signups_data, left_on='Name', right_on='Lead')

# %%
signups_leads_calls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1612 entries, 0 to 1611
# Data columns (total 10 columns):
# Phone Number         1612 non-null int64
# Call Outcome         1612 non-null object
# Agent                1612 non-null object
# Call Number          1612 non-null int64
# Name                 1612 non-null object
# Region               1612 non-null object
# Sector               1612 non-null object
# Age                  1612 non-null int64
# Lead                 1612 non-null object
# Approval Decision    1612 non-null object
# dtypes: int64(3), object(7)
# memory usage: 138.5+ KB

# %%
signups_leads_calls.groupby('Lead')['Lead'].count().mean()
# Out:
# 2.0989583333333335

# %% [markdown]
# Or

# %%
signups_leads_calls.shape[0]/signups_data.shape[0]
# Out:
# 2.0989583333333335

# %%
signups_leads_calls.head()
# Out:
#    Phone Number     Call Outcome   Agent  Call Number               Name  \
# 0  906739234066  CALL BACK LATER  orange            4  Lisette NICHOLSON
# 1  906739234066       INTERESTED  orange          104  Lisette NICHOLSON
# 2  568031927923       INTERESTED    blue           10        Tyree TERRY
# 3    1590010071       INTERESTED   green           11         Ansel WOOD
# 4  549140541574       INTERESTED     red           15        Ludwig DIAZ
#
#        Region         Sector  Age               Lead Approval Decision
# 0  south-west           food   25  Lisette NICHOLSON          REJECTED
# 1  south-west           food   25  Lisette NICHOLSON          REJECTED
# 2  north-west           food   32        Tyree TERRY          APPROVED
# 3    scotland  entertainment   51         Ansel WOOD          REJECTED
# 4  north-west         retail   30        Ludwig DIAZ          APPROVED

# %% [markdown]
# Find out which agent has most signups

# %%
# We filter by 'INTERESTED' in order to only keep the last call that make the lead sign up.
signups_leads_calls[signups_leads_calls['Call Outcome'] == 'INTERESTED'].groupby('Agent')['Agent'].count().sort_values(ascending = False)
# Out:
# Agent
# red       316
# orange    284
# green      67
# blue       52
# black      49
# Name: Agent, dtype: int64

# %% [markdown]
# It is interesting to see that although Agent Orange made most calls, Agent red got most of the signups.

# %% [markdown]
# Note that the above conclusion is based on the assumption that all agents called sametype of leads. This is an over-restrictive assumption. For example, Agent red may be just lucky to call leads who are more likely to sign up based on their characteristic variables.
#
# Note also that not necessarily those leads who are interested will sign up.

# %%
signups_leads_calls_all = pd.merge(leads_calls_left, signups_data, how = 'left', left_on = 'Name', right_on = 'Lead')
signups_leads_calls_all[signups_leads_calls_all['Call Outcome'] == 'INTERESTED'].head(20)
# Out:
#                  Name  Phone Number            Region         Sector  Age  \
# 3        Deangelo LEE  937521423043        north-west         retail   38
# 12        Lu JACOBSON  477236163516        north-west    consultancy   28
# 16       Theron WELCH  533788208390        north-east  entertainment   36
# 19        Lilia OCHOA   80967872849        north-west      wholesale   33
# 31   Cheryle CALDWELL  484404817049        north-west    consultancy   27
# 36       Naoma DURHAM  940509676942        south-east  entertainment   30
# 56     Alyssa HAMPTON  593981680906        north-east    consultancy   27
# 72        Glen PATTON  532155164354          midlands           food   20
# 88   Christena KRAMER  379624957194          scotland           food   32
# 101   Bonnie CALLAHAN  350965802992          scotland           food   27
# 114    Maverick AVERY  517932529206        north-east         retail   23
# 123    Lanette FRANCO  211763723387        north-west  entertainment   54
# 128       Boris BAUER  221762821828             wales    consultancy   22
# 145   Kathlyn CARLSON  151564849463        north-east    consultancy   30
# 152  Nehemiah KRUEGER  908794485710        north-west      wholesale   32
# 161       Wash MARTIN  112856659703            london    agriculture   30
# 176    Eulalia HUGHES  739194310736  northern-ireland    consultancy   28
# 179  Brittney TREVINO  194304533254        north-east           food   20
# 181         Lee GIBBS  866787583210        north-west  entertainment   18
# 198   Bernice MENDOZA  856716511479        south-west         retail   21
#
#     Call Outcome   Agent  Call Number              Lead Approval Decision
# 3     INTERESTED  orange       2413.0      Deangelo LEE          APPROVED
# 12    INTERESTED  orange       2149.0       Lu JACOBSON          REJECTED
# 16    INTERESTED   green       1207.0      Theron WELCH          APPROVED
# 19    INTERESTED   black       1333.0               NaN               NaN
# 31    INTERESTED  orange        473.0               NaN               NaN
# 36    INTERESTED   black       2013.0      Naoma DURHAM          REJECTED
# 56    INTERESTED  orange       2292.0    Alyssa HAMPTON          REJECTED
# 72    INTERESTED     red       2400.0       Glen PATTON          APPROVED
# 88    INTERESTED  orange       4067.0               NaN               NaN
# 101   INTERESTED     red       1753.0   Bonnie CALLAHAN          APPROVED
# 114   INTERESTED  orange       3262.0               NaN               NaN
# 123   INTERESTED    blue       4749.0    Lanette FRANCO          APPROVED
# 128   INTERESTED    blue       4656.0       Boris BAUER          REJECTED
# 145   INTERESTED  orange       2107.0               NaN               NaN
# 152   INTERESTED  orange       3562.0               NaN               NaN
# 161   INTERESTED     red       3376.0       Wash MARTIN          REJECTED
# 176   INTERESTED   black        410.0               NaN               NaN
# 179   INTERESTED   black       3578.0  Brittney TREVINO          REJECTED
# 181   INTERESTED    blue       1960.0         Lee GIBBS          APPROVED
# 198   INTERESTED     red        436.0               NaN               NaN

# %% [markdown]
# We can see that there are cases where an Agent has successfully made a lead interested but the lead didn't sign up.

# %% [markdown]
# Next we want to check which agent tends to have the highest signups/calls ratio.

# %%
# answer to the most calls question
calls_per_agent = calls_data.groupby('Agent')['Agent'].count().sort_index()
# answer to the most signups question
signups_per_agent = signups_leads_calls.groupby('Lead').last().groupby('Agent')['Agent'].count().sort_index()
# divide between the two and sort it
signups_rate = (signups_per_agent / calls_per_agent).sort_values(ascending = False)
signups_rate
# Out:
# Agent
# blue      0.261307
# red       0.213802
# green     0.197640
# orange    0.127126
# black     0.065333
# Name: Agent, dtype: float64

# %% [markdown]
# Although Agent blue has the highest signups/calls ratio, he only made 199 calls in total, not even one tenth of the Agent orange, and he only made 52 signups, far less than those of Agent red.

# %% [markdown]
# Now we want to check whether the variation of average signups/calls ratio is statistically significant.

# %% [markdown]
# chi-square test can be used to test whether signups count is uniformlly distributed. Firstly we need to create a contingency table.

# %%
test_data = pd.concat([signups_per_agent, calls_per_agent - signups_per_agent], axis = 1)
test_data.columns = ['signups count', 'non-signups count']
test_data
# Out:
#         signups count  non-signups count
# Agent
# black              49                701
# blue               52                147
# green              67                272
# orange            284               1950
# red               316               1162

# %%
test_data.iloc[:,0].sum()
# Out:
# 768

# %% [markdown]
# Using our bare eye we can see that the distribution of the ratio of signups against non-signups count is disproportioinal.
# We can prove this by running chi-square test.

# %%
# I use list comprehension to decompose the dataframe into separate row vector.
chi2, p, dof, expected = stats.chi2_contingency([i for i in np.array(test_data)])
chi2, p
# Out:
# (121.00714102354999, 3.2548690463183682e-25)

# %% [markdown]
# From the p-value we can see that the variability between the agents signups per call is statistically significant.

# %%
ag_1 = [49, 701]
ag_2 = [52, 147]
ag_3 = [67, 272]
ag_4 = [284, 1950]
ag_5 = [316, 1162]
data = [ag_1, ag_2, ag_3, ag_4, ag_5]
chi2, p, dof, expected= stats.chi2_contingency(data)
chi2, p
# Out:
# (121.00714102354999, 3.2548690463183682e-25)

# %% [markdown]
# Next we dig into the characteristic features of leads and try to firstly find out leads from which region are more likely to be interested.

# %%
leads_calls_inner = pd.merge(calls_data, leads_data, how = 'inner', on = 'Phone Number')
leadsOrderByRegion = leads_calls_inner[leads_calls_inner['Call Outcome'] == 'INTERESTED'].groupby('Region')['Region'].count().sort_values(ascending = False)
leadsOrderByRegion
# Out:
# Region
# north-west          365
# south-west          161
# midlands            150
# north-east          139
# scotland            137
# south-east          136
# south                62
# london               56
# wales                50
# northern-ireland     40
# Name: Region, dtype: int64

# %% [markdown]
# We can see that leads from north-west are more likely to be interested.

# %% [markdown]
# then we can find out leads from which sector are more likely to be interested.

# %%
leadsOrderBySector = leads_calls_left[leads_calls_left['Call Outcome'] == 'INTERESTED'].groupby('Sector')['Sector'].count().sort_values(ascending = False)
leadsOrderBySector
# Out:
# Sector
# consultancy      301
# retail           290
# food             261
# wholesale        233
# entertainment    135
# construction      46
# agriculture       30
# Name: Sector, dtype: int64

# %% [markdown]
# We can see that leads from consultancy sector are more likely to be interested.

# %% [markdown]
# Given leads who have expressed interests and signed up, we want to find out leads from which region are more likely to be approved.

# %%
# We can use signups_leads_calls for this purpose since data included only covers those leads who have signed up.
signups_leads_calls_clean = signups_leads_calls[signups_leads_calls['Call Outcome'] == 'INTERESTED']
signups_per_region = signups_leads_calls_clean.groupby('Region')['Region'].count().sort_index()
approved_per_region = signups_leads_calls_clean[signups_leads_calls_clean['Approval Decision'] == 'APPROVED'].groupby('Region')['Region'].count().sort_index()
(approved_per_region/signups_per_region).sort_values(ascending = False)
# Out:
# Region
# north-west          0.452381
# scotland            0.451220
# south               0.375000
# south-east          0.337209
# midlands            0.285714
# northern-ireland    0.250000
# south-west          0.245098
# north-east          0.243902
# wales               0.147059
# london              0.080000
# Name: Region, dtype: float64

# %% [markdown]
# We can see that leads from north-west region are more likely to be approved and the difference in approval rate is large across different regions.

# %% [markdown]
# We can run the same Chi-square test to see whether such difference is statistically different as well.

# %%
test_data = pd.concat([approved_per_region, signups_per_region - approved_per_region], axis = 1)
chi2, p, dof, expected = stats.chi2_contingency(test_data)
chi2, p
# Out:
# (39.42630068904591, 9.650022101968577e-06)

# %% [markdown]
# Unsurprisingly, the variation in approved rate is statistically significant across different regions.

# %% [markdown]
# Next, we want to build up a forecasting model for signups by firstly including the three characteristic features, i.e. age, region and sector.

# %%
in_sample = signups_leads_calls_all[(signups_leads_calls_all['Call Outcome'] == 'INTERESTED') | (signups_leads_calls_all['Call Outcome'] == 'NOT INTERESTED')]
# Because the modelling results are not satisfactory, let me try to include all Call Outcome 
temp_data = pd.merge(calls_data, leads_data, on = 'Phone Number', how = 'right')
out_sample = temp_data[temp_data['Call Outcome'].isnull()]

# %% [markdown]
# Create a data transformation pipeline for in-sample data

# %%
def data_pipeline(data, selected_cols, target_index, char_cols, char_orders, mapper):
    data = data.loc[:, selected_cols]
    for index, char_col in enumerate(char_cols):
        cat_type = CategoricalDtype(categories = char_orders[index], ordered = True)
        data[char_col] = data[char_col].astype(cat_type).values
        data = data.join(pd.get_dummies(data[char_col]))
#         To reduce the right skewness of variable 'Age' 
        data['Age'] = np.log(data['Age'])
    target_col = data[selected_cols[target_index]].map(mapper)
    data.insert(0, 'target', target_col)
    data = data.drop(selected_cols[target_index], axis = 1)
    data = data.drop(char_cols, axis = 1)
    return data

# %%
# in_sample_vars = ['Approval Decision', 'Age', 'Sector', 'Region']
in_sample_vars = ['Call Outcome', 'Age', 'Sector', 'Region']
out_sample_vars = ['Phone Number','Name', 'Age', 'Sector', 'Region']
char_col =  ['Region', 'Sector']
char_order = [leadsOrderByRegion.index, leadsOrderBySector.index]
# in_sample_mapper = {'APPROVED':1, 'REJECTED':1, None:0}
in_sample_mapper = {'INTERESTED':1, 'NOT INTERESTED':0}
out_sample_mapper = {}

final_in_sample = data_pipeline(in_sample, in_sample_vars, 0, char_col, char_order, in_sample_mapper)
final_out_sample = data_pipeline(out_sample, out_sample_vars, 0, char_col, char_order, out_sample_mapper)

train_set, test_set = train_test_split(final_in_sample, test_size = 0.2, random_state = 42)
X_train = train_set.iloc[:, 1:]
Y_train = train_set.iloc[:, 0]
X_test = test_set.iloc[:, 1:]
Y_test = test_set.iloc[:, 0]
X_full = final_in_sample.iloc[:, 1:]
Y_full = final_in_sample.iloc[:, 0]

# %%
# train_set[train_set['Call Outcome'] == 'INTERESTED']
train_set[train_set['target'] == 0]
# Out:
#        target       Age  north-west  south-west  midlands  north-east  \
# 8647        0  1.142787           0           0         0           1
# 10368       0  1.097189           0           0         0           1
# 7224        0  1.233722           0           0         0           1
# 1498        0  1.097189           0           0         0           0
# 7384        0  1.224128           0           0         0           1
# 9256        0  1.318462           0           0         1           0
# 1339        0  1.061385           0           0         0           0
# 5244        0  1.128508           0           0         0           1
# 10170       0  1.061385           0           0         0           0
# 5233        0  1.061385           0           0         1           0
# 11155       0  1.318462           0           0         0           1
# 1408        0  1.409607           1           0         0           0
# 5167        0  1.298436           1           0         0           0
# 6253        0  1.342510           0           0         0           0
# 8265        0  1.156269           0           1         0           0
# 4627        0  1.388126           1           0         0           0
# 7471        0  1.374030           0           1         0           0
# 3036        0  1.224128           1           0         0           0
# 6218        0  1.353565           0           0         0           0
# 5857        0  1.142787           1           0         0           0
# 7605        0  1.405493           1           0         0           0
# 11951       0  1.348111           1           0         0           0
# 3344        0  1.233722           0           0         0           0
# 11492       0  1.242925           0           0         0           0
# 4350        0  1.324738           0           0         0           0
# 5448        0  1.113344           0           0         1           0
# 6782        0  1.276345           0           0         0           0
# 3952        0  1.181143           0           1         0           0
# 9824        0  1.214110           0           0         1           0
# 11612       0  1.291320           0           0         0           0
# ...       ...       ...         ...         ...       ...         ...
# 11331       0  1.560704           0           0         0           0
# 4916        0  1.097189           0           0         1           0
# 9752        0  1.061385           0           0         0           1
# 787         0  1.533578           0           0         0           1
# 5047        0  1.388126           0           0         0           0
# 10996       0  1.156269           0           1         0           0
# 190         0  1.268453           0           0         0           0
# 3907        0  1.353565           1           0         0           0
# 6879        0  1.305323           0           0         1           0
# 10518       0  1.260266           0           0         0           0
# 10055       0  1.113344           1           0         0           0
# 10160       0  1.142787           0           1         0           0
# 3030        0  1.291320           0           0         0           0
# 10821       0  1.142787           0           0         0           0
# 3318        0  1.588794           1           0         0           0
# 9330        0  1.342510           0           1         0           0
# 934         0  1.388126           0           0         1           0
# 8899        0  1.276345           1           0         0           0
# 10090       0  1.439718           0           0         0           0
# 125         0  1.113344           0           0         0           0
# 11909       0  1.061385           0           0         0           0
# 7461        0  1.181143           0           0         0           0
# 3887        0  1.425247           0           0         1           0
# 1665        0  1.417583           0           0         0           0
# 6073        0  1.342510           1           0         0           0
# 10657       0  1.283962           0           0         0           0
# 5350        0  1.324738           0           0         0           1
# 5552        0  1.311994           0           0         0           0
# 6382        0  1.156269           0           1         0           0
# 4301        0  1.358877           0           1         0           0
#
#        scotland  south-east  south  london  wales  northern-ireland  \
# 8647          0           0      0       0      0                 0
# 10368         0           0      0       0      0                 0
# 7224          0           0      0       0      0                 0
# 1498          0           1      0       0      0                 0
# 7384          0           0      0       0      0                 0
# 9256          0           0      0       0      0                 0
# 1339          1           0      0       0      0                 0
# 5244          0           0      0       0      0                 0
# 10170         0           0      0       0      0                 1
# 5233          0           0      0       0      0                 0
# 11155         0           0      0       0      0                 0
# 1408          0           0      0       0      0                 0
# 5167          0           0      0       0      0                 0
# 6253          0           1      0       0      0                 0
# 8265          0           0      0       0      0                 0
# 4627          0           0      0       0      0                 0
# 7471          0           0      0       0      0                 0
# 3036          0           0      0       0      0                 0
# 6218          0           1      0       0      0                 0
# 5857          0           0      0       0      0                 0
# 7605          0           0      0       0      0                 0
# 11951         0           0      0       0      0                 0
# 3344          0           1      0       0      0                 0
# 11492         1           0      0       0      0                 0
# 4350          0           0      1       0      0                 0
# 5448          0           0      0       0      0                 0
# 6782          1           0      0       0      0                 0
# 3952          0           0      0       0      0                 0
# 9824          0           0      0       0      0                 0
# 11612         0           1      0       0      0                 0
# ...         ...         ...    ...     ...    ...               ...
# 11331         0           0      0       0      1                 0
# 4916          0           0      0       0      0                 0
# 9752          0           0      0       0      0                 0
# 787           0           0      0       0      0                 0
# 5047          0           1      0       0      0                 0
# 10996         0           0      0       0      0                 0
# 190           0           1      0       0      0                 0
# 3907          0           0      0       0      0                 0
# 6879          0           0      0       0      0                 0
# 10518         0           0      0       0      1                 0
# 10055         0           0      0       0      0                 0
# 10160         0           0      0       0      0                 0
# 3030          0           0      0       0      1                 0
# 10821         0           0      0       0      0                 1
# 3318          0           0      0       0      0                 0
# 9330          0           0      0       0      0                 0
# 934           0           0      0       0      0                 0
# 8899          0           0      0       0      0                 0
# 10090         0           0      1       0      0                 0
# 125           0           0      0       0      1                 0
# 11909         1           0      0       0      0                 0
# 7461          0           0      0       0      1                 0
# 3887          0           0      0       0      0                 0
# 1665          0           1      0       0      0                 0
# 6073          0           0      0       0      0                 0
# 10657         1           0      0       0      0                 0
# 5350          0           0      0       0      0                 0
# 5552          0           0      1       0      0                 0
# 6382          0           0      0       0      0                 0
# 4301          0           0      0       0      0                 0
#
#        consultancy  retail  food  wholesale  entertainment  construction  \
# 8647             0       0     1          0              0             0
# 10368            0       1     0          0              0             0
# 7224             0       1     0          0              0             0
# 1498             0       0     0          0              0             1
# 7384             0       0     1          0              0             0
# 9256             0       0     0          1              0             0
# 1339             0       1     0          0              0             0
# 5244             0       0     0          0              0             1
# 10170            0       0     0          1              0             0
# 5233             1       0     0          0              0             0
# 11155            0       0     0          1              0             0
# 1408             0       0     1          0              0             0
# 5167             0       1     0          0              0             0
# 6253             1       0     0          0              0             0
# 8265             0       1     0          0              0             0
# 4627             0       0     0          0              0             0
# 7471             0       1     0          0              0             0
# 3036             0       0     0          0              1             0
# 6218             0       1     0          0              0             0
# 5857             0       0     0          0              0             1
# 7605             0       0     1          0              0             0
# 11951            0       0     0          1              0             0
# 3344             1       0     0          0              0             0
# 11492            0       1     0          0              0             0
# 4350             0       0     0          0              0             0
# 5448             0       0     0          1              0             0
# 6782             0       0     0          0              1             0
# 3952             0       1     0          0              0             0
# 9824             1       0     0          0              0             0
# 11612            0       1     0          0              0             0
# ...            ...     ...   ...        ...            ...           ...
# 11331            0       0     1          0              0             0
# 4916             0       1     0          0              0             0
# 9752             0       0     0          1              0             0
# 787              0       1     0          0              0             0
# 5047             0       0     0          0              1             0
# 10996            0       1     0          0              0             0
# 190              0       1     0          0              0             0
# 3907             0       0     0          0              0             1
# 6879             0       0     0          0              0             0
# 10518            0       0     0          0              0             0
# 10055            0       1     0          0              0             0
# 10160            0       1     0          0              0             0
# 3030             0       1     0          0              0             0
# 10821            0       0     1          0              0             0
# 3318             0       1     0          0              0             0
# 9330             0       1     0          0              0             0
# 934              0       0     0          1              0             0
# 8899             0       0     0          0              1             0
# 10090            0       0     1          0              0             0
# 125              1       0     0          0              0             0
# 11909            0       0     1          0              0             0
# 7461             0       0     0          1              0             0
# 3887             0       0     1          0              0             0
# 1665             0       0     0          1              0             0
# 6073             0       0     0          0              0             1
# 10657            0       0     0          0              0             0
# 5350             0       0     1          0              0             0
# 5552             0       1     0          0              0             0
# 6382             0       1     0          0              0             0
# 4301             0       1     0          0              0             0
#
#        agriculture
# 8647             0
# 10368            0
# 7224             0
# 1498             0
# 7384             0
# 9256             0
# 1339             0
# 5244             0
# 10170            0
# 5233             0
# 11155            0
# 1408             0
# 5167             0
# 6253             0
# 8265             0
# 4627             1
# 7471             0
# 3036             0
# 6218             0
# 5857             0
# 7605             0
# 11951            0
# 3344             0
# 11492            0
# 4350             1
# 5448             0
# 6782             0
# 3952             0
# 9824             0
# 11612            0
# ...            ...
# 11331            0
# 4916             0
# 9752             0
# 787              0
# 5047             0
# 10996            0
# 190              0
# 3907             0
# 6879             1
# 10518            1
# 10055            0
# 10160            0
# 3030             0
# 10821            0
# 3318             0
# 9330             0
# 934              0
# 8899             0
# 10090            0
# 125              0
# 11909            0
# 7461             0
# 3887             0
# 1665             0
# 6073             0
# 10657            1
# 5350             0
# 5552             0
# 6382             0
# 4301             0
#
# [959 rows x 19 columns]

# %%
#  Fine tunning Logistic regression
from sklearn.model_selection import GridSearchCV
LogR = LogisticRegression(solver= 'liblinear', random_state=50)

# import statsmodels.formula.api as sm
# LogR0 = sm.Logit(Y_train, X_train)
# results = LogR0.fit()
# results.params
param_grid = {
     'penalty' : ['l1', 'l2'],
    'C' : np.logspace(-2, 2, 20),
    'class_weight': ['balanced', None],
    'solver' : ['liblinear']}
temp = LogisticRegression(random_state = 50)
grid_search = GridSearchCV(temp, param_grid, cv = 10)
grid_search.fit(X_train, Y_train)
aug_LogR = grid_search.best_estimator_
[LogR.get_params, aug_LogR.get_params]
# Out:
# [<bound method BaseEstimator.get_params of LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#            intercept_scaling=1, max_iter=100, multi_class='warn',
#            n_jobs=None, penalty='l2', random_state=50, solver='liblinear',
#            tol=0.0001, verbose=0, warm_start=False)>,
#  <bound method BaseEstimator.get_params of LogisticRegression(C=0.06951927961775606, class_weight=None, dual=False,
#            fit_intercept=True, intercept_scaling=1, max_iter=100,
#            multi_class='warn', n_jobs=None, penalty='l2', random_state=50,
#            solver='liblinear', tol=0.0001, verbose=0, warm_start=False)>]

# %%
from sklearn.model_selection import cross_val_predict, cross_val_score
from sklearn.metrics import precision_score, recall_score, roc_auc_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV

RandForest = RandomForestClassifier(n_estimators=100, random_state = 50)

temp = RandomForestClassifier(random_state = 50)
param_grid = {'n_estimators': [int(x) for x in np.linspace(start = 100, stop = 1000, num = 10)],
               'max_features': ['auto', 'sqrt'],
               'max_depth': [int(x) for x in np.linspace(10, 110, num = 11)],
               'min_samples_split': [2, 5, 10],
               'min_samples_leaf': [1, 2, 4],
               'bootstrap': [True, False]}

random_grid = RandomizedSearchCV(estimator = temp, param_distributions = param_grid, n_iter = 50, cv = 5, verbose=2, random_state=50, n_jobs = -1)
random_grid.fit(X_train, Y_train)
aug_RandForest = random_grid.best_estimator_
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   21.1s
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 250 out of 250 | elapsed:  2.5min finished

# %%
[cross_val_score(LogR, X_full, Y_full, cv = 5), cross_val_score(aug_LogR, X_full, Y_full, cv = 5), cross_val_score(RandForest, X_full, Y_full, cv = 5), cross_val_score(aug_RandForest, X_full, Y_full, cv = 5)]
# Out:
# [array([0.62624254, 0.65269461, 0.64071856, 0.65868263, 0.62075848]),
#  array([0.62624254, 0.65269461, 0.62674651, 0.65868263, 0.64071856]),
#  array([0.58648111, 0.56087824, 0.53093812, 0.55688623, 0.53692615]),
#  array([0.59642147, 0.6247505 , 0.5748503 , 0.63073852, 0.60279441])]

# %%
[RandForest.get_params, aug_RandForest.get_params]
# Out:
# [<bound method BaseEstimator.get_params of RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#              max_depth=None, max_features='auto', max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#              oob_score=False, random_state=50, verbose=0, warm_start=False)>,
#  <bound method BaseEstimator.get_params of RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#              max_depth=70, max_features='auto', max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=4, min_samples_split=10,
#              min_weight_fraction_leaf=0.0, n_estimators=600, n_jobs=None,
#              oob_score=False, random_state=50, verbose=0, warm_start=False)>]

# %%
model_dict = {'logistic' : LogR, 
        'tuned logistic' : aug_LogR, 
        'random forest' : RandForest, 
        'tuned random forest' : aug_RandForest}

validation_dict = {'precision' : precision_score,
                  'recall' : recall_score,
                  'roc_auc' : roc_auc_score}

for key in model_dict:
    model_dict[key].fit(X_train, Y_train)

def output_table(model_f, val_f, X, Y, pred_f = None):
    out = []
    for key1 in model_f.keys():
        if pred_f == None:
            Y_predict = model_f[key1].predict(X)
        else:
            Y_predict = pred_f(model_f[key1], X, Y, cv = 10)
        for key2 in val_f.keys():
            out.append(val_f[key2](Y, Y_predict))
    cols = len(val_f)
    rows = len(model_f)
    out = np.array(out)
    out.shape = (rows, cols)
    out = pd.DataFrame(out, index=model_f.keys(), columns=val_f.keys())
    return out
[LogR.coef_, aug_LogR.coef_]
# Out:
# [array([[-0.37793425,  0.60914159,  0.4363232 , -0.60425131, -0.18617069,
#          -0.23387347,  0.01194474, -0.14904875,  1.48598785, -0.6606915 ,
#          -0.22735238,  0.86291872, -0.52371939,  0.02080468,  0.59466066,
#           0.28335261, -0.70892056, -0.04708746]]),
#  array([[-0.0477804 ,  0.52818561,  0.34995491, -0.49218562, -0.12430482,
#          -0.16943933,  0.01937853, -0.08930823,  0.63646746, -0.42475767,
#          -0.10705501,  0.66343909, -0.52368232, -0.05267253,  0.42250993,
#           0.1706423 , -0.50025654, -0.05304409]])]

# %%
# We can have a look at the modelling performance of all four models in the training sample
output_table(model_dict, validation_dict, X_train, Y_train, cross_val_predict)
# Out:
#                      precision    recall   roc_auc
# logistic              0.651445  0.668260  0.639135
# tuned logistic        0.647215  0.699809  0.641875
# random forest         0.590020  0.576482  0.569784
# tuned random forest   0.627181  0.652964  0.614803

# %%
# We can have a look at the forecasting performance of four models in the test sample
output_table(model_dict, validation_dict, X_test, Y_test)
# Out:
#                      precision  recall   roc_auc
# logistic              0.614035   0.700  0.631746
# tuned logistic        0.604651   0.728  0.627889
# random forest         0.571429   0.640  0.581905
# tuned random forest   0.574468   0.648  0.585905

# %% [markdown]
# Because of the poor modelling performance in the test sample, I suspect that by dropping some less important predictors, the overfitting issue could be reduced.

# %%
in_sample = signups_leads_calls_all[(signups_leads_calls_all['Call Outcome'] == 'INTERESTED')]
in_sample_vars = ['Approval Decision', 'Age', 'Sector', 'Region']
out_sample_vars = ['Phone Number','Name', 'Age', 'Sector', 'Region']
char_col =  ['Region', 'Sector']
char_order = [leadsOrderByRegion.index, leadsOrderBySector.index]
in_sample_mapper = {'APPROVED':1, 'REJECTED':1, None:0}
out_sample_mapper = {}

final_in_sample = data_pipeline(in_sample, in_sample_vars, 0, char_col, char_order, in_sample_mapper)
final_out_sample = data_pipeline(out_sample, out_sample_vars, 0, char_col, char_order, out_sample_mapper)

train_set, test_set = train_test_split(final_in_sample, test_size = 0.2, random_state = 42)
X_train = train_set.iloc[:, 1:]
Y_train = train_set.iloc[:, 0]
X_test = test_set.iloc[:, 1:]
Y_test = test_set.iloc[:, 0]
X_full = final_in_sample.iloc[:, 1:]
Y_full = final_in_sample.iloc[:, 0]

# %%
Y_train
# Out:
# 3382     0
# 11970    1
# 12083    0
# 6911     0
# 3492     1
# 3762     0
# 12165    0
# 2570     0
# 8216     0
# 1218     1
# 10969    0
# 2819     1
# 8169     1
# 11053    0
# 8128     1
# 1437     1
# 11353    1
# 10740    0
# 3476     1
# 10803    1
# 5636     1
# 7818     1
# 8233     0
# 839      0
# 12091    1
# 2966     0
# 5710     1
# 1434     0
# 4260     1
# 5019     1
#         ..
# 6868     1
# 4878     1
# 10390    0
# 4565     1
# 8204     0
# 7270     1
# 2422     1
# 223      0
# 4432     0
# 11246    1
# 2726     0
# 9203     1
# 11480    1
# 3789     1
# 7836     1
# 3428     0
# 7455     0
# 1160     0
# 8321     1
# 10733    1
# 767      0
# 3300     1
# 11678    0
# 4487     0
# 1058     0
# 10049    0
# 10516    1
# 10772    0
# 8228     1
# 10744    0
# Name: target, Length: 1036, dtype: int64

# %%
LogR_2nd = LogisticRegression(solver= 'liblinear', random_state=50)

param_grid = {
     'penalty' : ['l1', 'l2'],
    'C' : np.logspace(-2, 2, 20),
    'class_weight': ['balanced', None],
    'solver' : ['liblinear']}
temp = LogisticRegression(random_state = 50)
grid_search = GridSearchCV(temp, param_grid, cv = 10)
grid_search.fit(X_train, Y_train)
aug_LogR_2nd = grid_search.best_estimator_
[LogR_2nd.get_params, aug_LogR_2nd.get_params]
# Out:
# [<bound method BaseEstimator.get_params of LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#            intercept_scaling=1, max_iter=100, multi_class='warn',
#            n_jobs=None, penalty='l2', random_state=50, solver='liblinear',
#            tol=0.0001, verbose=0, warm_start=False)>,
#  <bound method BaseEstimator.get_params of LogisticRegression(C=0.06951927961775606, class_weight=None, dual=False,
#            fit_intercept=True, intercept_scaling=1, max_iter=100,
#            multi_class='warn', n_jobs=None, penalty='l2', random_state=50,
#            solver='liblinear', tol=0.0001, verbose=0, warm_start=False)>]

# %%
from sklearn.model_selection import cross_val_predict, cross_val_score
from sklearn.metrics import precision_score, recall_score, roc_auc_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV

RandForest_2nd = RandomForestClassifier(n_estimators=100, random_state = 50)

temp = RandomForestClassifier(random_state = 50)
param_grid = {'n_estimators': [int(x) for x in np.linspace(start = 100, stop = 1000, num = 10)],
               'max_features': ['auto', 'sqrt'],
               'max_depth': [int(x) for x in np.linspace(10, 110, num = 11)],
               'min_samples_split': [2, 5, 10],
               'min_samples_leaf': [1, 2, 4],
               'bootstrap': [True, False]}

random_grid = RandomizedSearchCV(estimator = temp, param_distributions = param_grid, n_iter = 50, cv = 5, verbose=2, random_state = 50, n_jobs = -1)
random_grid.fit(X_train, Y_train)
aug_RandForest_2nd = random_grid.best_estimator_
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   12.1s
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:   57.9s
# [Parallel(n_jobs=-1)]: Done 250 out of 250 | elapsed:  1.5min finished

# %%
model_dict_2nd = {'logistic 2nd' : LogR_2nd, 
        'tuned logistic 2nd' : aug_LogR_2nd, 
        'random forest 2nd' : RandForest_2nd, 
        'tuned random 2nd' : aug_RandForest_2nd}
output_table(model_dict_2nd, validation_dict, X_train, Y_train, cross_val_predict)
# Out:
#                     precision    recall   roc_auc
# logistic 2nd         0.602911  0.933977  0.506748
# tuned logistic 2nd   0.602172  0.982287  0.505601
# random forest 2nd    0.596899  0.619968  0.496731
# tuned random 2nd     0.606178  0.758454  0.510552

# %%
[cross_val_score(LogR_2nd, X_full, Y_full, cv = 5), cross_val_score(aug_LogR_2nd, X_full, Y_full, cv = 5), cross_val_score(RandForest_2nd, X_full, Y_full, cv = 5), cross_val_score(aug_RandForest_2nd, X_full, Y_full, cv = 5)]
# Out:
# [array([0.59615385, 0.6       , 0.58076923, 0.58914729, 0.57364341]),
#  array([0.6       , 0.6       , 0.59230769, 0.59302326, 0.59302326]),
#  array([0.51153846, 0.50769231, 0.52307692, 0.54651163, 0.51550388]),
#  array([0.56153846, 0.50769231, 0.53461538, 0.56976744, 0.55426357])]

# %%
for key in model_dict_2nd:
    model_dict_2nd[key].fit(X_train, Y_train)
output_table(model_dict_2nd, validation_dict, X_test, Y_test)
# Out:
#                     precision    recall   roc_auc
# logistic 2nd         0.567797  0.911565  0.504455
# tuned logistic 2nd   0.572000  0.972789  0.512943
# random forest 2nd    0.585987  0.625850  0.525315
# tuned random 2nd     0.597938  0.789116  0.549425

# %%
# I may call this block on the failed logistic regression
from sklearn.ensemble import ExtraTreesClassifier
model = ExtraTreesClassifier(n_estimators = 50)
model.fit(X_train, Y_train)
importance = pd.Series(model.feature_importances_)
features = pd.Series(X_train.columns)
importance_table = pd.concat([features, importance], axis = 1)
importance_table.columns = ['feature', 'importance']
importance_table.sort_values('importance', ascending = False)
# Out:
#              feature  importance
# 0                Age    0.851168
# 5           scotland    0.012975
# 6         south-east    0.012191
# 2         south-west    0.010860
# 14         wholesale    0.009903
# 3           midlands    0.009872
# 1         north-west    0.009740
# 12            retail    0.009412
# 13              food    0.009031
# 7              south    0.008559
# 4         north-east    0.008373
# 8             london    0.008025
# 17       agriculture    0.007507
# 11       consultancy    0.007384
# 10  northern-ireland    0.006744
# 9              wales    0.006597
# 15     entertainment    0.006427
# 16      construction    0.005232

# %%
# I need to cache it.
# Try to improve the model performance in the test sample by focusing on those important features only
final_in_sample_shrinked = final_in_sample[['target', 'Age', 'south-west', 'midlands', 'london', 'consultancy', 'retail', 'food', 'wholesale', 'construction']]
train_set, test_set = train_test_split(final_in_sample_shrinked, test_size = 0.2, random_state = 42)
X_train = train_set.iloc[:, 1:]
Y_train = train_set.iloc[:, 0]
X_test = test_set.iloc[:, 1:]
Y_test = test_set.iloc[:, 0]

LogR_shrinked = LogisticRegression(solver= 'liblinear')

param_grid = {
     'penalty' : ['l1', 'l2'],
    'C' : np.logspace(-5, 5, 20),
    'class_weight': ['balanced', None],
    'solver' : ['liblinear']}
temp = LogisticRegression()
grid_search = GridSearchCV(temp, param_grid, cv = 10)
grid_search.fit(X_train, Y_train)
aug_LogR_shrinked = grid_search.best_estimator_

[LogR_shrinked.get_params, aug_LogR_shrinked.get_params]
# Out:
# [<bound method BaseEstimator.get_params of LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#            intercept_scaling=1, max_iter=100, multi_class='warn',
#            n_jobs=None, penalty='l2', random_state=None, solver='liblinear',
#            tol=0.0001, verbose=0, warm_start=False)>,
#  <bound method BaseEstimator.get_params of LogisticRegression(C=1e-05, class_weight='balanced', dual=False,
#            fit_intercept=True, intercept_scaling=1, max_iter=100,
#            multi_class='warn', n_jobs=None, penalty='l1', random_state=None,
#            solver='liblinear', tol=0.0001, verbose=0, warm_start=False)>]

# %%
model_dict_shrinked = {'logistic_shirnked' : LogR_shrinked, 
        'tuned logistic_shrinked' : aug_LogR_shrinked}
LogR_shrinked.fit(X_train, Y_train)
aug_LogR_shrinked.fit(X_train, Y_train)
output_table(model_dict_shrinked, validation_dict, X_train, Y_train, cross_val_predict)
# Out:
# E:\Anaconda\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# E:\Anaconda\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
#                          precision  recall  roc_auc
# logistic_shirnked              0.0     0.0      0.5
# tuned logistic_shrinked        0.0     0.0      0.5

# %%
output_table(model_dict_shrinked, validation_dict, X_test, Y_test)
# Out:
# E:\Anaconda\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# E:\Anaconda\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
#                          precision  recall  roc_auc
# logistic_shirnked              0.0     0.0      0.5
# tuned logistic_shrinked        0.0     0.0      0.5

# %% [markdown]
# As expected, because less predictors are used, the modelling performance in the training sample is worsen off. In addition, there is little improvement in the test sample even though the predictor set is reduced. Therefore, this exercise shall focus on using random forest classifier and fine tuned random forecast classifer for the following analysis.

# %%
np.log(in_sample['Age']).hist()

# %% [markdown]
# We now try to select 1000 leads from those uncalled. I use the predicted probability from random foreset classifier to rank them.(the higher the proability, the more likely the leads sign up)

# %%
X_out_sample = final_out_sample.iloc[:, 2:]
Y_forecast = RandForest.predict_proba(X_out_sample)
largest_1000_index = np.argsort(Y_forecast[:, 1])[-1000:]
selected_name_RandForest = final_out_sample.iloc[largest_1000_index, 1]
selected_name_RandForest = pd.DataFrame(selected_name_RandForest)
selected_name_RandForest
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-122-8bfc08a0e4af> in <module>
#       1 X_out_sample = final_out_sample.iloc[:, 2:]
# ----> 2 Y_forecast = RandForest.predict_proba(X_out_sample)
#       3 largest_1000_index = np.argsort(Y_forecast[:, 1])[-1000:]
#       4 selected_name_RandForest = final_out_sample.iloc[largest_1000_index, 1]
#       5 selected_name_RandForest = pd.DataFrame(selected_name_RandForest)
#
# E:\Anaconda\lib\site-packages\sklearn\ensemble\forest.py in predict_proba(self, X)
#     579             classes corresponds to that in the attribute `classes_`.
#     580         """
# --> 581         check_is_fitted(self, 'estimators_')
#     582         # Check data
#     583         X = self._validate_X_predict(X)
#
# E:\Anaconda\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#     949
#     950     if not all_or_any([hasattr(estimator, attr) for attr in attributes]):
# --> 951         raise NotFittedError(msg % {'name': type(estimator).__name__})
#     952
#     953
#
# NotFittedError: This RandomForestClassifier instance is not fitted yet. Call 'fit' with appropriate arguments before using this method.

# %%
X_out_sample = final_out_sample.iloc[:, 2:]
Y_forecast = aug_RandForest.predict_proba(X_out_sample)
largest_1000_index = np.argsort(Y_forecast[:, 1])[-1000:]
selected_name_aug_RandForest = final_out_sample.iloc[largest_1000_index, 1]
selected_name_aug_RandForest = pd.DataFrame(selected_name_aug_RandForest)

# %%
pd.merge(selected_name_RandForest, selected_name_aug_RandForest, on = 'Name')
# Out:
#                    Name
# 0          Kala HIGGINS
# 1        Deeann COMPTON
# 2            Cyrus PARK
# 3      Clifford SCHULTZ
# 4        Brandan MATHIS
# 5           Reina ZHANG
# 6          Walter VANCE
# 7           Alexa SLOAN
# 8            Sage HENRY
# 9            Ashly TATE
# 10        Adrien WALKER
# 11            Sid MAYER
# 12        Elayne DUARTE
# 13         Ericka COHEN
# 14       Pearlie NEWMAN
# 15      Bobbie CRAWFORD
# 16        Lynda BARAJAS
# 17      Maryanne JACOBS
# 18          Ahmed PRATT
# 19        Abigale HICKS
# 20      Emelie FIGUEROA
# 21   Germaine SINGLETON
# 22          Elian MARKS
# 23         Colby CASTRO
# 24       Shirley JARVIS
# 25          Jaren SHORT
# 26       Katharine SHEA
# 27          Blair TERRY
# 28        Shakira NIXON
# 29        Autumn HOWARD
# ..                  ...
# 497      Omer MCFARLAND
# 498      Willie HANCOCK
# 499          Rosco SHAH
# 500         Sal HERRING
# 501        Beryl BURTON
# 502     Martell BRENNAN
# 503        Oswald REESE
# 504        Arley TUCKER
# 505        Aileen BARRY
# 506        Royce LARSON
# 507    Vinnie BLACKBURN
# 508        Ruthie PRATT
# 509      Shirlene KIRBY
# 510       Doris HOLLAND
# 511     Lillie CISNEROS
# 512      Anthony HODGES
# 513      Daron GALLEGOS
# 514        Amani ARNOLD
# 515      Earline HESTER
# 516        Harold PEREZ
# 517           Hyman LIN
# 518         Booker HESS
# 519      Shelby MAYNARD
# 520         Candy OWENS
# 521      Jefferey CASEY
# 522      Reece RANDOLPH
# 523       Bernice BAUER
# 524       Bama JENNINGS
# 525       Louvenia LUTZ
# 526    Francisco SUTTON
#
# [527 rows x 1 columns]

# %% [markdown]
# We can see that random forest and fine tuned random forest have similar prediction for the 1000 most likely signuped leads, i.e. over 900 out of 1000 overlapped.

# %% [markdown]
# Finnaly, we want to check by taking all four characteristic features into account, which agent tend to reach more signups in the called leads.

# %%
in_sample_vars = ['Approval Decision', 'Age', 'Sector', 'Region', 'Agent']
char_col =  ['Region', 'Sector', 'Agent']
char_order = [leadsOrderByRegion.index, leadsOrderBySector.index, signups_rate.index]
in_sample_mapper = {'APPROVED':1, 'REJECTED':1, None:0}
final_in_sample_extended = data_pipeline(in_sample, in_sample_vars, 0, char_col, char_order, in_sample_mapper)
train_set, test_set = train_test_split(final_in_sample_extended, test_size = 0.2, random_state = 42)
X_train = train_set.iloc[:, 1:]
Y_train = train_set.iloc[:, 0]
X_test = test_set.iloc[:, 1:]
Y_test = test_set.iloc[:, 0]
X_full = final_in_sample_extended.iloc[:, 1:]
Y_full = final_in_sample_extended.iloc[:, 0]

# %%
in_sample
# Out:
#                     Name  Phone Number      Region         Sector  Age  \
# 1           Deangelo LEE  937521423043  north-west         retail   38
# 2           Deangelo LEE  937521423043  north-west         retail   38
# 3           Deangelo LEE  937521423043  north-west         retail   38
# 6             Sarah POPE  264176984341    midlands         retail   18
# 11           Lu JACOBSON  477236163516  north-west    consultancy   28
# 12           Lu JACOBSON  477236163516  north-west    consultancy   28
# 15          Theron WELCH  533788208390  north-east  entertainment   36
# 16          Theron WELCH  533788208390  north-east  entertainment   36
# 19           Lilia OCHOA   80967872849  north-west      wholesale   33
# 20       Rosalind HORTON  804443519963       wales           food   32
# 22         Addison JONES  183488745758  south-west         retail   45
# 23         Addison JONES  183488745758  south-west         retail   45
# 28      Cheryle CALDWELL  484404817049  north-west    consultancy   27
# 29      Cheryle CALDWELL  484404817049  north-west    consultancy   27
# 30      Cheryle CALDWELL  484404817049  north-west    consultancy   27
# 31      Cheryle CALDWELL  484404817049  north-west    consultancy   27
# 32         Tyree HARRELL  779853839503    scotland  entertainment   38
# 33         Tyree HARRELL  779853839503    scotland  entertainment   38
# 36          Naoma DURHAM  940509676942  south-east  entertainment   30
# 38         Wylie WALTERS  406980633299       south           food   40
# 54        Alyssa HAMPTON  593981680906  north-east    consultancy   27
# 55        Alyssa HAMPTON  593981680906  north-east    consultancy   27
# 56        Alyssa HAMPTON  593981680906  north-east    consultancy   27
# 61        Joanie SANTANA  850074421651    midlands           food   40
# 65        Konner JOHNSON  769819934152    scotland      wholesale   18
# 66        Konner JOHNSON  769819934152    scotland      wholesale   18
# 67           Ray STANTON  523787984735  south-east   construction   26
# 68           Ray STANTON  523787984735  south-east   construction   26
# 69           Ray STANTON  523787984735  south-east   construction   26
# 70           Ray STANTON  523787984735  south-east   construction   26
# ...                  ...           ...         ...            ...  ...
# 12203    Bernie SCHAEFER  239267384303  south-west         retail   26
# 12204    Bernie SCHAEFER  239267384303  south-west         retail   26
# 12205    Enrique ROLLINS  854814997126       south           food   67
# 12207      Andria HOLDEN  360867972464    midlands      wholesale   38
# 12211      Kayla ESCOBAR  769780174056    midlands      wholesale   20
# 12212      Kayla ESCOBAR  769780174056    midlands      wholesale   20
# 12221   Mallory GUERRERO  324622091508  north-west         retail   46
# 12222    Stan STEPHENSON  379232815493  south-west         retail   21
# 12223    Stan STEPHENSON  379232815493  south-west         retail   21
# 12224    Stan STEPHENSON  379232815493  south-west         retail   21
# 12225    Stan STEPHENSON  379232815493  south-west         retail   21
# 12226    Stan STEPHENSON  379232815493  south-west         retail   21
# 12232     Corbin BENNETT  116374395940  north-west           food   36
# 12233     Corbin BENNETT  116374395940  north-west           food   36
# 12234     Corbin BENNETT  116374395940  north-west           food   36
# 12241   Daniel RASMUSSEN  110408008418  south-west         retail   49
# 12242   Daniel RASMUSSEN  110408008418  south-west         retail   49
# 12245    Geralyn ROWLAND  519275713372  south-west         retail   51
# 12246    Geralyn ROWLAND  519275713372  south-west         retail   51
# 12247    Myranda RICHARD  782952452296       south           food   24
# 12251        Cayla STONE  873540973102  north-east      wholesale   56
# 12252        Cayla STONE  873540973102  north-east      wholesale   56
# 12253        Cayla STONE  873540973102  north-east      wholesale   56
# 12260    Novella VAUGHAN  606392795807  north-east           food   26
# 12261    Novella VAUGHAN  606392795807  north-east           food   26
# 12262    Novella VAUGHAN  606392795807  north-east           food   26
# 12268  Marcia RICHARDSON  875785853728    midlands   construction   88
# 12273      Dallas MOSLEY  450781977953       south           food   97
# 12274      Dallas MOSLEY  450781977953       south           food   97
# 12275      Dallas MOSLEY  450781977953       south           food   97
#
#           Call Outcome   Agent  Call Number             Lead Approval Decision
# 1      CALL BACK LATER   black       2213.0     Deangelo LEE          APPROVED
# 2      CALL BACK LATER  orange       2313.0     Deangelo LEE          APPROVED
# 3           INTERESTED  orange       2413.0     Deangelo LEE          APPROVED
# 6       NOT INTERESTED     red       3211.0              NaN               NaN
# 11     CALL BACK LATER   green       2049.0      Lu JACOBSON          REJECTED
# 12          INTERESTED  orange       2149.0      Lu JACOBSON          REJECTED
# 15      ANSWER MACHINE     red       1107.0     Theron WELCH          APPROVED
# 16          INTERESTED   green       1207.0     Theron WELCH          APPROVED
# 19          INTERESTED   black       1333.0              NaN               NaN
# 20      NOT INTERESTED  orange        915.0              NaN               NaN
# 22      ANSWER MACHINE     red       2066.0              NaN               NaN
# 23      NOT INTERESTED  orange       2166.0              NaN               NaN
# 28     CALL BACK LATER  orange        173.0              NaN               NaN
# 29     CALL BACK LATER     red        273.0              NaN               NaN
# 30     CALL BACK LATER   black        373.0              NaN               NaN
# 31          INTERESTED  orange        473.0              NaN               NaN
# 32     CALL BACK LATER     red       1446.0              NaN               NaN
# 33      NOT INTERESTED   black       1546.0              NaN               NaN
# 36          INTERESTED   black       2013.0     Naoma DURHAM          REJECTED
# 38           DEAD LINE   black       1705.0              NaN               NaN
# 54     CALL BACK LATER  orange       2092.0   Alyssa HAMPTON          REJECTED
# 55     CALL BACK LATER  orange       2192.0   Alyssa HAMPTON          REJECTED
# 56          INTERESTED  orange       2292.0   Alyssa HAMPTON          REJECTED
# 61           DEAD LINE   green       2174.0              NaN               NaN
# 65     CALL BACK LATER  orange       1891.0              NaN               NaN
# 66      NOT INTERESTED  orange       1991.0              NaN               NaN
# 67     CALL BACK LATER  orange        680.0              NaN               NaN
# 68     CALL BACK LATER  orange        780.0              NaN               NaN
# 69     CALL BACK LATER     red        880.0              NaN               NaN
# 70      NOT INTERESTED   black        980.0              NaN               NaN
# ...                ...     ...          ...              ...               ...
# 12203   ANSWER MACHINE  orange       4485.0              NaN               NaN
# 12204   NOT INTERESTED   black       4585.0              NaN               NaN
# 12205   NOT INTERESTED   black       2706.0              NaN               NaN
# 12207   NOT INTERESTED  orange       1030.0              NaN               NaN
# 12211   ANSWER MACHINE   black       4315.0              NaN               NaN
# 12212   NOT INTERESTED   black       4415.0              NaN               NaN
# 12221   NOT INTERESTED  orange       3438.0              NaN               NaN
# 12222   ANSWER MACHINE   green        470.0  Stan STEPHENSON          APPROVED
# 12223  CALL BACK LATER     red        570.0  Stan STEPHENSON          APPROVED
# 12224  CALL BACK LATER  orange        670.0  Stan STEPHENSON          APPROVED
# 12225  CALL BACK LATER     red        770.0  Stan STEPHENSON          APPROVED
# 12226       INTERESTED  orange        870.0  Stan STEPHENSON          APPROVED
# 12232  CALL BACK LATER     red       3854.0              NaN               NaN
# 12233  CALL BACK LATER  orange       3954.0              NaN               NaN
# 12234   NOT INTERESTED  orange       4054.0              NaN               NaN
# 12241   ANSWER MACHINE  orange         30.0              NaN               NaN
# 12242   NOT INTERESTED  orange        130.0              NaN               NaN
# 12245   ANSWER MACHINE     red       1741.0              NaN               NaN
# 12246   NOT INTERESTED     red       1841.0              NaN               NaN
# 12247       INTERESTED     red       4022.0  Myranda RICHARD          APPROVED
# 12251   ANSWER MACHINE  orange        223.0      Cayla STONE          REJECTED
# 12252  CALL BACK LATER  orange        323.0      Cayla STONE          REJECTED
# 12253       INTERESTED    blue        423.0      Cayla STONE          REJECTED
# 12260  CALL BACK LATER  orange       3694.0              NaN               NaN
# 12261  CALL BACK LATER  orange       3794.0              NaN               NaN
# 12262       INTERESTED   black       3894.0              NaN               NaN
# 12268   NOT INTERESTED     red        547.0              NaN               NaN
# 12273  CALL BACK LATER   black       4413.0              NaN               NaN
# 12274  CALL BACK LATER     red       4513.0              NaN               NaN
# 12275   NOT INTERESTED  orange       4613.0              NaN               NaN
#
# [5000 rows x 10 columns]

# %%
from sklearn.ensemble import ExtraTreesClassifier
model = ExtraTreesClassifier(n_estimators = 50)
model.fit(X_train, Y_train)
importance = pd.Series(model.feature_importances_)
features = pd.Series(X_train.columns)
importance_table = pd.concat([features, importance], axis = 1)
importance_table.columns = ['feature', 'importance']
importance_table.sort_values('importance', ascending = False)
# Out:
#              feature  importance
# 0                Age    0.781474
# 2         south-west    0.013736
# 13              food    0.013384
# 22             black    0.013359
# 12            retail    0.013312
# 19               red    0.012153
# 8             london    0.011365
# 11       consultancy    0.011331
# 3           midlands    0.011274
# 14         wholesale    0.010922
# 6         south-east    0.010501
# 1         north-west    0.010173
# 5           scotland    0.010035
# 15     entertainment    0.009526
# 21            orange    0.009404
# 16      construction    0.008909
# 9              wales    0.007899
# 4         north-east    0.007798
# 7              south    0.007265
# 18              blue    0.007186
# 10  northern-ireland    0.007051
# 17       agriculture    0.005981
# 20             green    0.005963

# %%
from sklearn.model_selection import GridSearchCV

LogR_extended = LogisticRegression(solver= 'liblinear')
LogR_extended.fit(X_train, Y_train)

param_grid = {
     'penalty' : ['l1', 'l2'],
    'C' : np.logspace(-5, 5, 20),
    'class_weight': ['balanced', None],
    'solver' : ['liblinear']}
temp = LogisticRegression()
grid_search = GridSearchCV(temp, param_grid, cv = 10)
grid_search.fit(X_train, Y_train)
aug_LogR_extended = grid_search.best_estimator_
[LogR_extended.get_params, aug_LogR_extended.get_params]
# Out:
# [<bound method BaseEstimator.get_params of LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#            intercept_scaling=1, max_iter=100, multi_class='warn',
#            n_jobs=None, penalty='l2', random_state=None, solver='liblinear',
#            tol=0.0001, verbose=0, warm_start=False)>,
#  <bound method BaseEstimator.get_params of LogisticRegression(C=0.04832930238571752, class_weight=None, dual=False,
#            fit_intercept=True, intercept_scaling=1, max_iter=100,
#            multi_class='warn', n_jobs=None, penalty='l2', random_state=None,
#            solver='liblinear', tol=0.0001, verbose=0, warm_start=False)>]

# %%
RandForest_extended = RandomForestClassifier(n_estimators=100)

temp = RandomForestClassifier()
param_grid = {'n_estimators': [int(x) for x in np.linspace(start = 200, stop = 2000, num = 10)],
               'max_features': ['auto', 'sqrt'],
               'max_depth': [int(x) for x in np.linspace(10, 110, num = 11)],
               'min_samples_split': [2, 5, 10],
               'min_samples_leaf': [1, 2, 4],
               'bootstrap': [True, False]}

random_grid = RandomizedSearchCV(estimator = temp, param_distributions = param_grid, n_iter = 50, cv = 5, verbose=2, random_state=42, n_jobs = -1)
random_grid.fit(X_train, Y_train)
aug_RandForest_extended = random_grid.best_estimator_
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   56.7s
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=-1)]: Done 250 out of 250 | elapsed:  6.7min finished

# %%
[RandForest_extended.get_params, aug_LogR_extended.get_params]
# Out:
# [<bound method BaseEstimator.get_params of RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#              max_depth=None, max_features='auto', max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#              oob_score=False, random_state=None, verbose=0,
#              warm_start=False)>,
#  <bound method BaseEstimator.get_params of LogisticRegression(C=0.04832930238571752, class_weight=None, dual=False,
#            fit_intercept=True, intercept_scaling=1, max_iter=100,
#            multi_class='warn', n_jobs=None, penalty='l2', random_state=None,
#            solver='liblinear', tol=0.0001, verbose=0, warm_start=False)>]

# %%
[cross_val_score(LogR_extended, X_full, Y_full, cv = 5), cross_val_score(aug_LogR_extended, X_full, Y_full, cv = 5), cross_val_score(RandForest_extended, X_full, Y_full, cv = 5), cross_val_score(aug_RandForest_extended, X_full, Y_full, cv = 5)]
# Out:
# [array([0.67432567, 0.66933067, 0.68      , 0.68468468, 0.67567568]),
#  array([0.67632368, 0.67732268, 0.677     , 0.68668669, 0.68168168]),
#  array([0.61438561, 0.61038961, 0.592     , 0.63763764, 0.57357357]),
#  array([0.62537463, 0.63036963, 0.623     , 0.63463463, 0.58658659])]

# %%
model_dict_extended = {'logistic extended':LogR_extended, 
        'tuned logistic extended':aug_LogR_extended, 
        'random forest extended':RandForest_extended, 
        'tuned random forest extended':aug_RandForest_extended}

validation_dict = {'precision':precision_score,
                  'recall':recall_score,
                  'roc_auc':roc_auc_score}

for key in model_dict_extended:
    model_dict_extended[key].fit(X_train, Y_train)

# %%
output_table(model_dict_extended, validation_dict, X_train, Y_train, cross_val_predict)
# Out:
#                               precision    recall   roc_auc
# logistic extended              0.500000  0.096875  0.525643
# tuned logistic extended        0.545455  0.046875  0.514246
# random forest extended         0.530414  0.510938  0.649035
# tuned random forest extended   0.543112  0.428125  0.629320

# %%
# RandForest_extended.fit(X_train, Y_train)
# Y_predict = cross_val_predict(RandForest_extended, X_train, Y_train, cv = 10)
# # precision_score(Y_predict, Y_train)
# roc_auc_score(Y_predict, Y_train)
aug_RandForest_extended.fit(X_train, Y_train)
Y_predict = cross_val_predict(aug_RandForest_extended, X_train, Y_train, cv = 10)
roc_auc_score(Y_predict, Y_train)
# Out:
# 0.6455677340309283

# %%
output_table(model_dict_extended, validation_dict, X_test, Y_test)
# Out:
#                               precision    recall   roc_auc
# logistic extended              0.515625  0.099398  0.526495
# tuned logistic extended        0.400000  0.030120  0.503833
# random forest extended         0.537415  0.475904  0.636155
# tuned random forest extended   0.528384  0.364458  0.601391

# %% [markdown]
# Now we can run regression to see the predicted leads for each agent by setting each of the agent to be 1 and dropping the others

# %%
X_agent = X_train
signups_predict = np.zeros(5)
Agent = ['blue', 'red', 'green', 'orange', 'black']
for i in range(5):
    extend = np.zeros(5)
    extend[i] = 1
    X_agent[Agent] = extend
    signups_predict[i] = sum(RandForest_extended.predict(X_agent))

signups_predict = pd.Series(signups_predict)
signups_predict.index = Agent
signups_predict
# Out:
# blue      1415.0
# red       1532.0
# green     1255.0
# orange    1091.0
# black      613.0
# dtype: float64

# %% [markdown]
# signups_predict records the total predicted signups by each agent. We can tell that Agent red has the maximum signups while Agent blue reaches the second. So I would choose Agent red to call every lead. On average the expected leads are

# %%
signups_predict.mean()
# Out:
# 1181.2
